# %%
from pycaret.datasets import get_data
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
# Out:
# In /home/mihhail/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mihhail/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mihhail/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/mihhail/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
vehicle_data = pd.read_csv('vehicle_price(2020).csv')

# %%
vehicle_data.head()
# Out:
#            brand     model  year   body  price$  car_mileage    fuel  power  \
# 0           ford   transit  2006  other   5 350          220  diesel    2.0
# 1        renault    master  2017  other  17 000          211  diesel    2.3
# 2           opel    vivaro  2015  other  15 200          157  diesel    1.6
# 3           ford   transit  2000  other   4 999          300  diesel    2.4
# 4  mercedes-benz  sprinter  2010  other  20 700          682  diesel    3.0
#
#   transmission
# 0       manual
# 1       manual
# 2       manual
# 3       manual
# 4    automatic

# %%
from pycaret.regression import *
exp1 = setup(vehicle_data,transformation=False,normalize_method='robust',target = 'price$',silent = False,train_size=0.7)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
# #T_a4f538a6_40ae_11eb_a944_b91bb7fda991row4_col1{
#             background-color:  yellow;
#         }</style><table id="T_a4f538a6_40ae_11eb_a944_b91bb7fda991" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4f538a6_40ae_11eb_a944_b91bb7fda991level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a4f538a6_40ae_11eb_a944_b91bb7fda991row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_a4f538a6_40ae_11eb_a944_b91bb7fda991row0_col1" class="data row0 col1" >8417</td>
#             </tr>
#             <tr>
#                         <th id="T_a4f538a6_40ae_11eb_a944_b91bb7fda991level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models(blacklist = ['ransac','tr','svm'])
# Out:
# <style  type="text/css" >
#     #T_40f793aa_40b1_11eb_a944_b91bb7fda991 th {
#           text-align: left;
# ...

# %%
catboost = create_model(estimator = 'catboost',fold = 10, max_depth = 9, cross_validation = True, verbose = True, system = True,learning_rate=0.07)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Value Error): Estimator Not Available. Please see docstring for list of available estimators.

# %%
tuned_catboost = tune_model(catboost)

# %%
save_model(tuned_catboost, 'vehicleCatboostModell')
# Out:
# Transformation Pipeline and Model Succesfully Saved
